# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_8cc493db86234f6780ee1a2a6cc689a9 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='Pwb0-KFo0m4BxB7v0Y0o_-lKn6rFouvAz820gWjRgtxv',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_8cc493db86234f6780ee1a2a6cc689a9.get_object(Bucket='sesion4challengecrisp-donotdelete-pr-qo6sjszjk2ctfh',Key='data-1595040833478.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#    id  numero  tipo  pie       fecha  total                     created_at  \
# 0   3      82     0    0  2016-03-07  54000  2016-09-08 15:59:57.953595+00
# 1   3      82     0    0  2016-03-07  54000  2016-09-08 15:59:57.953595+00
# 2   3      82     0    0  2016-03-07  54000  2016-09-08 15:59:57.953595+00
# 3   6      19     0    0  2016-02-16  48000  2016-09-08 15:59:58.085858+00
# 4   6      19     0    0  2016-02-16  48000  2016-09-08 15:59:58.085858+00
#
#                       updated_at  id_cliente  id_vendedor  ...  \
# 0  2017-01-06 01:15:35.349026+00           4            1  ...
# 1  2017-01-06 01:15:35.349026+00           4            1  ...
# 2  2017-01-06 01:15:35.349026+00           4            1  ...
# 3  2017-01-05 23:38:20.147831+00           7            1  ...
# 4  2017-01-05 23:38:20.147831+00           7            1  ...
#
#    fecha_vencimiento  estado-2                   created_at-4  \
# 0         2016-05-30         1  2017-01-06 01:15:35.365979+00
# ...

# %%
df_c = df_data_1.groupby(['numero','nombre-2', 'id_libro'])

# %%
df_c['pie', 'id_libro', 'nombre-2'].head()
# Out:
#         pie  id_libro                              nombre-2
# 0         0        80          Lexus editores de chile s.a.
# 1         0        80          Lexus editores de chile s.a.
# 2         0        80          Lexus editores de chile s.a.
# 3         0        68          Lexus editores de chile s.a.
# 4         0        68          Lexus editores de chile s.a.
# 5         0        68          Lexus editores de chile s.a.
# 6         0        68          Lexus editores de chile s.a.
# 7         0        14          Lexus editores de chile s.a.
# 8         0        14          Lexus editores de chile s.a.
# 9         0        14          Lexus editores de chile s.a.
# 10        0        14          Lexus editores de chile s.a.
# 11        0       136                           Caligrafix
# 12        0       137                           Caligrafix
# 13        0        26  Bibliográfica internacional limitada
# 14        0        26  Bibliográfica internacional limitada
# ...

# %%
df_data_1.columns
# Out:
# Index(['id', 'numero', 'tipo', 'pie', 'fecha', 'total', 'created_at',
#        'updated_at', 'id_cliente', 'id_vendedor', 'cuotas_totales', 'estado',
#        'id-2', 'cantidad', 'precio', 'id_libro', 'id_venta', 'id-3', 'nombre',
#        'stock', 'stock_critico', 'created_at-2', 'updated_at-2',
#        'id_editorial', 'id-4', 'nombre-2', 'telefono', 'correo', 'pais',
#        'created_at-3', 'updated_at-3', 'id-5', 'valor', 'abono',
#        'fecha_vencimiento', 'estado-2', 'created_at-4', 'updated_at-4',
#        'id_recaudador', 'id_venta-2', 'numero-2', 'is_printed', 'version',
#        'payment_date'],
#       dtype='object')
